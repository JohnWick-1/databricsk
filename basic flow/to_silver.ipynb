# %%
# df  = spark.read('playground_1.bronze.student3')

df = spark.table('playground_1.bronze.student3')
# df.show()
# df.count()
# df = df.dropDuplicates().dropna()

# %%
df = df.dropDuplicates().dropna()
# df.count()

# %%
df.write.mode('overwrite').saveAsTable('playground_1.silver.student3')

# %%
# %sql
-- select count(1) from playground_1.silver.student3
-- drop table playground_1.silver.student3
