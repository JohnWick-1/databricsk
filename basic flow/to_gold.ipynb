# %%
# %sql
-- select * from playground_1.silver.student3 limit 5

-- select School_DBN, sum(Present) from playground_1.silver.student3 group by School_DBN

# %%
from pyspark.sql import functions as f
df = spark.table('playground_1.silver.student3')
#  select School_DBN, sum(Present) from playground_1.silver.student3 group by School_DBN

df = df.groupBy('School_DBN').agg(
    f.sum(f.col('Present')).alias('total_present')
)

# %%
df.write.mode('overwrite').saveAsTable('playground_1.gold.student3')

# %%
# %sql
-- select * from  playground_1.gold.student3
