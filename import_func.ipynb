# %%
# %sql
# CREATE OR REPLACE FUNCTION concate_two(price DOUBLE, payment_method STRING)
# RETURNS STRING
# RETURN concat(price, '-', payment_method);

# %%
# %sql
-- -- select product_category, price, payment_method from playground_1.mydb.amazon_sales_dataset limit 6;

-- select product_category, price, payment_method, concate_two(price,payment_method) as concated  from playground_1.mydb.amazon_sales_dataset limit 6;

# %%
# %run "/Workspace/practice_sessions/constant"

# %%
df = spark.read.format('csv').option("header", "true").load('/Volumes/playground_1/mydb/volume_1/amazon_sales_dataset.csv')

# %%
df.show(1)

# %%
# from pyspark.sql import functions as f

# df.withColumn('abc', concate_two(f.col("customer_region"), f.col("customer_region")))
# display(df.select("customer_region", ).limit(5))
